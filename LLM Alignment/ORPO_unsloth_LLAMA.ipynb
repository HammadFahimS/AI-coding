# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = "/content/drive/My Drive/Thesis/Datasets/Multilabel/AnnotationWorks/"

# %%
# %pip install -q datasets trl bitsandbytes peft unsloth
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 32.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 45.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 95.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.4/116.4 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu124 requires torch==2.5.1, but you have torch 2.6.0 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# fastai 2.7.18 requires torch<2.6,>=1.10, but you have torch 2.6.0 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<6.0.0dev,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.

# %%
#HF_TOKEN = "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"
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `Multiclass` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `Multiclass`

# %%
#WANDB_TOKEN = "75f3b5cf11636fb593faa3285610d6496b933167"
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: hammad-fahim57 (hammad-fahim57-university-of-ottawa) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
import pandas as pd
try:
  preference_dataset_tt = pd.read_csv(dataset_path + "FOR_DPO_TEST.csv")
  print("Dataset loaded successfully.")
except FileNotFoundError:
  print(f"Error: File 'preference_dataset.csv' not found at {dataset_path}")
except pd.errors.EmptyDataError:
  print(f"Error: 'preference_dataset.csv' is empty.")
except pd.errors.ParserError:
  print(f"Error: Unable to parse 'preference_dataset.csv'. Check file format.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# Dataset loaded successfully.

# %%
try:
  preference_dataset_tr = pd.read_csv(dataset_path + "FOR_DPO_TRAIN.csv")
  print("Dataset loaded successfully.")
except FileNotFoundError:
  print(f"Error: File 'preference_dataset.csv' not found at {dataset_path}")
except pd.errors.EmptyDataError:
  print(f"Error: 'preference_dataset.csv' is empty.")
except pd.errors.ParserError:
  print(f"Error: Unable to parse 'preference_dataset.csv'. Check file format.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# Dataset loaded successfully.

# %%
len(preference_dataset_tt)
# Out:
# 567

# %%
len(preference_dataset_tr)
# Out:
# 928

# %%
preference_dataset_tt.columns
# Out:
# Index(['ID', 'Tweet', 'gold_multilabel', 'explanation_1',
#        'predicted_multilabel_1', 'predicted_single_1', 'explanation_2',
#        'predicted_multilabel_2', 'predicted_single_2', 'Correct',
#        'gold_multilabel_corrected', 'response1', 'response2',
#        'Correct_response', 'chosen_response', 'clarity_1', 'correctness_1',
#        'helpfulness_1', 'verbosity_1', 'clarity_2', 'correctness_2',
#        'helpfulness_2', 'verbosity_2', 'overall_1', 'overall_2',
#        'fixed_chosen_explanation'],
#       dtype='object')

# %%
preference_dataset_tr.columns
# Out:
# Index(['ID', 'Tweet', 'gold_multilabel', 'gold_multilabel_corrected', 'Prompt',
#        'explanation_1', 'predicted_multilabel_1', 'predicted_single_1',
#        'explanation_2', 'predicted_multilabel_2', 'predicted_single_2',
#        'response_1', 'response_2', 'Correct', 'Correct_response'],
#       dtype='object')

# %%
preference_dataset_tt = preference_dataset_tt.rename(columns={'response1': 'response_1', 'response2': 'response_2'})

# %%
for col in preference_dataset_tt.columns:
  print(col, type(preference_dataset_tt[col][0]))
# Out:
# ID <class 'str'>
# Tweet <class 'str'>
# gold_multilabel <class 'str'>
# explanation_1 <class 'str'>
# predicted_multilabel_1 <class 'str'>
# predicted_single_1 <class 'str'>
# explanation_2 <class 'str'>
# predicted_multilabel_2 <class 'str'>
# predicted_single_2 <class 'str'>
# Correct <class 'numpy.int64'>
# gold_multilabel_corrected <class 'str'>
# response_1 <class 'str'>
# response_2 <class 'str'>
# Correct_response <class 'numpy.int64'>
# chosen_response <class 'numpy.float64'>
# clarity_1 <class 'numpy.float64'>
# correctness_1 <class 'numpy.float64'>
# helpfulness_1 <class 'numpy.float64'>
# verbosity_1 <class 'numpy.float64'>
# clarity_2 <class 'numpy.float64'>
# correctness_2 <class 'numpy.float64'>
# helpfulness_2 <class 'numpy.float64'>
# verbosity_2 <class 'numpy.float64'>
# overall_1 <class 'numpy.float64'>
# overall_2 <class 'numpy.float64'>
# fixed_chosen_explanation <class 'numpy.float64'>

# %%
for col in preference_dataset_tr.columns:
  print(col, type(preference_dataset_tr[col][0]))
# Out:
# ID <class 'str'>
# Tweet <class 'str'>
# gold_multilabel <class 'str'>
# gold_multilabel_corrected <class 'str'>
# Prompt <class 'str'>
# explanation_1 <class 'str'>
# predicted_multilabel_1 <class 'str'>
# predicted_single_1 <class 'str'>
# explanation_2 <class 'str'>
# predicted_multilabel_2 <class 'str'>
# predicted_single_2 <class 'str'>
# response_1 <class 'str'>
# response_2 <class 'str'>
# Correct <class 'numpy.int64'>
# Correct_response <class 'numpy.int64'>

# %%
columns_to_keep = [
    'ID', 'Tweet', 'gold_multilabel',
    'explanation_1', 'explanation_2',
    'predicted_multilabel_1', 'predicted_single_1', 'response_1',
    'predicted_multilabel_2', 'predicted_single_2', 'response_2',
    'Correct_response'
]

# %%
preference_dataset_tr_m = preference_dataset_tr[columns_to_keep]
preference_dataset_tt_m = preference_dataset_tt[columns_to_keep]

# %%
merged_dataset = pd.concat([preference_dataset_tr_m, preference_dataset_tt_m], ignore_index=True)

# %%
merged_dataset.head()
# Out:
#               ID                                              Tweet  \
# 0  2017-En-21441  “Worry is a down payment on a problem you may ...
# 1  2017-En-41344  it's pretty depressing when u hit pan on ur fa...
# 2  2017-En-20759  @BossUpJaee but your pussy was weak from what ...
# 3  2017-En-30807  Your glee filled Normy dry humping of the most...
# 4  2017-En-11184        What a fucking muppet.  @jRwild1  #stalker.
#
#                          gold_multilabel  \
# 0  ['anticipation', 'optimism', 'trust']
# 1                 ['sadness', 'disgust']
# 2                   ['anger', 'disgust']
# 3                   ['anger', 'disgust']
# 4                   ['anger', 'disgust']
#
#                                        explanation_1  \
# 0  The tweet is a motivational quote by Joyce Mey...
# 1  The tweet expresses a sense of disappointment ...
# 2  The tweet displays a strong negative sentiment...
# 3  The tweet expresses a negative sentiment towar...
# 4  The tweet uses the phrase 'What a fucking mupp...
#
#                                        explanation_2  \
# 0  The tweet quotes Joyce Meyer, suggesting that ...
# 1  The tweet expresses a negative sentiment throu...
# 2  The tweet is filled with aggressive and confro...
# 3  The tweet expresses a strong negative sentimen...
# 4  The tweet uses the phrase 'What a fucking mupp...
#
#                   predicted_multilabel_1 predicted_single_1  \
# 0  ['optimism', 'anticipation', 'trust']            neutral
# 1                    ['sadness', 'love']            sadness
# 2                   ['anger', 'disgust']              anger
# 3                   ['anger', 'disgust']              anger
# 4                   ['anger', 'disgust']              anger
#
#                                           response_1  predicted_multilabel_2  \
# 0  {"explanation":"The tweet is a motivational qu...            ['optimism']
# 1  {"explanation":"The tweet expresses a sense of...  ['sadness', 'disgust']
# 2  {"explanation":"The tweet displays a strong ne...    ['anger', 'disgust']
# 3  {"explanation":"The tweet expresses a negative...    ['anger', 'disgust']
# 4  {"explanation":"The tweet uses the phrase 'Wha...    ['anger', 'disgust']
#
#   predicted_single_2                                         response_2  \
# 0            neutral  {"explanation":"The tweet quotes Joyce Meyer, ...
# 1            sadness  {"explanation":"The tweet expresses a negative...
# 2              anger  {"explanation":"The tweet is filled with aggre...
# 3              anger  {"explanation":"The tweet expresses a strong n...
# 4              anger  {"explanation":"The tweet uses the phrase 'Wha...
#
#    Correct_response
# 0                 1
# 1                 2
# 2                 1
# 3                 1
# 4                 1

# %%
merged_dataset.shape
# Out:
# (1495, 12)

# %%
user_prompt_format = """
Your task is to analyze the content of the given tweet and classify it based on the following emotion labels:

Emotion Labels: [anger, fear, love, surprise, sadness, joy, anticipation, disgust, optimism, pessimism, trust, neutral]

Tweet: "{}"

Instructions:

1. Analyze the Content: Thoroughly analyze the tweet's content, tone, and context. Look for linguistic cues, such as words, phrases, or implied sentiments that might indicate one or more emotions.

2. Chain of Thought Reasoning: Break down the tweet's components step by step. Consider the following questions as part of your reasoning:
  2a. What is the speaker expressing?
  2b. Does the speaker show a positive, negative, or neutral sentiment?
  2c. Are there hints of longing, hope, frustration, or any other specific emotion?
  2d. Is there any combination of emotions suggested by the words or tone?

3. Classify Emotions: Use the reasoning process to identify:
  3a. The Most Prominent Emotion: Select the single most dominant emotion that captures the essence of the tweet.
  3b. Other Present Emotions: List other emotions that might be present in the tweet, even if they are secondary.

4. Explain the Classification: Explain your classification. Clearly articulate:
  4a. Why did you choose the most prominent emotion?
  4b. Why do you believe the secondary emotions are present?
  4c. Reference specific parts of the tweet that support your reasoning.

5. If no emotions are present, then put neutral in both the most prominent emotion and other present emotions.
"""

# %%
# prompt: get subset of merged_dataset where predicted_multilabel_1 != predicted_multilabel_2

subset_dataset = merged_dataset[merged_dataset['predicted_multilabel_1'] != merged_dataset['predicted_multilabel_2']]
subset_dataset.head()
# Out:
#                ID                                              Tweet  \
# 0   2017-En-21441  “Worry is a down payment on a problem you may ...
# 1   2017-En-41344  it's pretty depressing when u hit pan on ur fa...
# 6   2017-En-30296  #smile every morning to a positive head start ...
# 9   2017-En-10649  I believe I'm gonna start singing in my snap s...
# 10  2017-En-21045  Jorge deserves it, honestly. He's weak.  #90da...
#
#                           gold_multilabel  \
# 0   ['anticipation', 'optimism', 'trust']
# 1                  ['sadness', 'disgust']
# 6                     ['joy', 'optimism']
# 9                 ['joy', 'anticipation']
# 10                   ['anger', 'disgust']
#
#                                         explanation_1  \
# 0   The tweet is a motivational quote by Joyce Mey...
# 1   The tweet expresses a sense of disappointment ...
# 6   The tweet encourages smiling every morning to ...
# 9   The tweet expresses a positive and light-heart...
# 10  The tweet expresses a negative sentiment towar...
#
#                                         explanation_2  \
# 0   The tweet quotes Joyce Meyer, suggesting that ...
# 1   The tweet expresses a negative sentiment throu...
# 6   The tweet encourages positivity and a good sta...
# 9   The tweet expresses a lighthearted and creativ...
# 10  The tweet expresses a negative sentiment towar...
#
#                    predicted_multilabel_1 predicted_single_1  \
# 0   ['optimism', 'anticipation', 'trust']            neutral
# 1                     ['sadness', 'love']            sadness
# 6                     ['joy', 'optimism']                joy
# 9                 ['joy', 'anticipation']                joy
# 10                            ['disgust']              anger
#
#                                            response_1  \
# 0   {"explanation":"The tweet is a motivational qu...
# 1   {"explanation":"The tweet expresses a sense of...
# 6   {"explanation":"The tweet encourages smiling e...
# 9   {"explanation":"The tweet expresses a positive...
# 10  {"explanation":"The tweet expresses a negative...
#
#                  predicted_multilabel_2 predicted_single_2  \
# 0                          ['optimism']            neutral
# 1                ['sadness', 'disgust']            sadness
# 6          ['joy', 'optimism', 'trust']                joy
# 9   ['joy', 'anticipation', 'optimism']                joy
# 10                 ['anger', 'disgust']              anger
#
#                                            response_2  Correct_response
# 0   {"explanation":"The tweet quotes Joyce Meyer, ...                 1
# 1   {"explanation":"The tweet expresses a negative...                 2
# 6   {"explanation":"The tweet encourages positivit...                 1
# 9   {"explanation":"The tweet expresses a lighthea...                 1
# 10  {"explanation":"The tweet expresses a negative...                 2

# %%
subset_dataset.shape
# Out:
# (963, 12)

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
import os
from trl import SFTTrainer, ORPOConfig, ORPOTrainer
from unsloth import FastLanguageModel, PatchDPOTrainer, is_bfloat16_supported
import tqdm
import random
from datasets import Dataset
from google.colab import drive
from transformers import Trainer, TrainingArguments, AutoTokenizer, BitsAndBytesConfig, AutoModelForCausalLM
from sklearn.model_selection import train_test_split
from peft import get_peft_model, LoraConfig
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
prompt = []
chosen = []
rejected = []

# %%
for index, row in subset_dataset.iterrows():
  prompt.append(user_prompt_format.format(row["Tweet"]))
  correct_response = row["Correct_response"]
  if correct_response == 1:
    chosen.append(row["response_1"])
    rejected.append(row["response_2"])
  elif correct_response == 2:
    chosen.append(row["response_2"])
    rejected.append(row["response_1"])

# %%
print(len(prompt))
print(len(chosen))
print(len(rejected))
# Out:
# 963
# 963
# 963

# %%
# prompt: create a new dataframe called dpo_dataframe, add three columns in the dataset namely prompt, chosen and rejected, which are the three lists int he last code block.

dpo_dataframe = pd.DataFrame({'prompt': prompt, 'chosen': chosen, 'rejected': rejected})

# %%
dpo_dataframe.head()
# Out:
#                                               prompt  \
# 0  \nYour task is to analyze the content of the g...
# 1  \nYour task is to analyze the content of the g...
# 2  \nYour task is to analyze the content of the g...
# 3  \nYour task is to analyze the content of the g...
# 4  \nYour task is to analyze the content of the g...
#
#                                               chosen  \
# 0  {"explanation":"The tweet is a motivational qu...
# 1  {"explanation":"The tweet expresses a negative...
# 2  {"explanation":"The tweet encourages smiling e...
# 3  {"explanation":"The tweet expresses a positive...
# 4  {"explanation":"The tweet expresses a negative...
#
#                                             rejected
# 0  {"explanation":"The tweet quotes Joyce Meyer, ...
# 1  {"explanation":"The tweet expresses a sense of...
# 2  {"explanation":"The tweet encourages positivit...
# 3  {"explanation":"The tweet expresses a lighthea...
# 4  {"explanation":"The tweet expresses a negative...

# %%
# prompt: Divide dpo_dataframe into train and eval sets. in 80:20 split

train_df, eval_df = train_test_split(dpo_dataframe, test_size=0.2, random_state=42)

# %%
train_df = train_df.reset_index(drop=True)
eval_df = eval_df.reset_index(drop=True)

# %%
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(eval_df)

# %%
max_seq_length = 1024
dtype = None
load_in_4bit = True

model, tokenizer = FastLanguageModel.from_pretrained(
    #model_name = "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    #model_name = "unsloth/DeepSeek-R1-Distill-Llama-8B-unsloth-bnb-4bit",
    model_name = "unsloth/DeepSeek-R1-Distill-Qwen-32B-bnb-4bit",
    #model_name = "unsloth/llama-3-8b-Instruct-bnb-4bit",
    max_seq_length=max_seq_length,
    dtype=dtype,
    load_in_4bit=load_in_4bit,
)


if tokenizer.pad_token is None:
    tokenizer.add_special_tokens({'pad_token': tokenizer.eos_token})
    model.resize_token_embeddings(tokenizer.vocab_size)
    print("Added padding token")
# Out:
# ==((====))==  Unsloth 2025.2.5: Fast Qwen2 patching. Transformers: 4.48.2.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.557 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 8.0. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json:   0%|          | 0.00/280k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/4.32G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/236 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/6.77k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]

# %%
model = FastLanguageModel.get_peft_model(model,
                                          r=16,
                                          target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                                                            "gate_proj", "up_proj", "down_proj",],
                                          lora_alpha = 16,
                                          lora_dropout = 0, # Supports any, but = 0 is optimized
                                          bias = "none",    # Supports any, but = "none" is optimized
                                          use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
                                          random_state = 3407,
                                          use_rslora = False,  # We support rank stabilized LoRA
                                          loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2025.2.5 patched 64 layers with 64 QKV layers, 64 O layers and 64 MLP layers.

# %%
# ORPO - Configuration and Trainer Setup
PatchDPOTrainer()  # Patch for DPO Trainer

# ORPO Trainer Setup
orpo_trainer = ORPOTrainer(
    model=model,
    train_dataset=train_dataset,  # Training dataset with chosen/rejected
    eval_dataset=val_dataset, # Validation dataset for evaluation during fine-tuning
    tokenizer=tokenizer,
    args=ORPOConfig(
        beta=0.1,
        max_length=1024,
        max_prompt_length=1024,
        per_device_train_batch_size=4,
        per_device_eval_batch_size=4,
        gradient_accumulation_steps=2,
        learning_rate=2e-4, #2e-4
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear", # "cosine"
        #num_train_epochs = 3, # 1 for full training run
        max_steps=100,  # None for full run (comment out if using num_train_epochs)
        fp16=not is_bfloat16_supported(),  # Use FP16 if BFloat16 isn't supported
        bf16=is_bfloat16_supported(),  # Use BFloat16 if available
        evaluation_strategy="steps",  # Enable evaluation during training
        eval_steps=10,
        output_dir="./orpo_results_DeepSeek-R1-Distill-Qwen-32B-bnb-4bit-ORPO",
        report_to="wandb", # "wandb"
    ),
)

# Begin ORPO fine-tuning
orpo_trainer.train()
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Map:   0%|          | 0/770 [00:00<?, ? examples/s]
# Map:   0%|          | 0/770 [00:00<?, ? examples/s]
# Map:   0%|          | 0/770 [00:00<?, ? examples/s]
# Map:   0%|          | 0/193 [00:00<?, ? examples/s]
# Map:   0%|          | 0/193 [00:00<?, ? examples/s]
# Map:   0%|          | 0/193 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 770 | Num Epochs = 2
# O^O/ \_/ \    Batch size per device = 4 | Gradient Accumulation steps = 2
# \        /    Total batch size = 8 | Total steps = 100
#  "-____-"     Number of trainable parameters = 134,217,728
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/content/wandb/run-20250211_160749-uy12xxfc</code>
# Syncing run <strong><a href='https://wandb.ai/hammad-fahim57-university-of-ottawa/huggingface/runs/uy12xxfc' target="_blank">./orpo_results_DeepSeek-R1-Distill-Qwen-32B-bnb-4bit-ORPO</a></strong> to <a href='https://wandb.ai/hammad-fahim57-university-of-ottawa/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/hammad-fahim57-university-of-ottawa/huggingface' target="_blank">https://wandb.ai/hammad-fahim57-university-of-ottawa/huggingface</a>
#  View run at <a href='https://wandb.ai/hammad-fahim57-university-of-ottawa/huggingface/runs/uy12xxfc' target="_blank">https://wandb.ai/hammad-fahim57-university-of-ottawa/huggingface/runs/uy12xxfc</a>
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 29:20, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>rewards / chosen</th>
#       <th>rewards / rejected</th>
#       <th>rewards / accuracies</th>
#       <th>rewards / margins</th>
#       <th>logps / chosen</th>
#       <th>logps / rejected</th>
#       <th>logits / chosen</th>
#       <th>logits / rejected</th>
#       <th>eval_logits / chosen</th>
#       <th>eval_logits / rejected</th>
#       <th>nll_loss</th>
#       <th>aux_loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.144600</td>
#       <td>0.549460</td>
#       <td>-0.072363</td>
#       <td>-0.075583</td>
#       <td>0.596939</td>
#       <td>0.003221</td>
#       <td>-0.723627</td>
#       <td>-0.755835</td>
#       <td>-1.810619</td>
#       <td>-1.811970</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.954200</td>
#       <td>0.466057</td>
#       <td>-0.066388</td>
#       <td>-0.070379</td>
#       <td>0.612245</td>
#       <td>0.003990</td>
#       <td>-0.663885</td>
#       <td>-0.703789</td>
#       <td>-1.868946</td>
#       <td>-1.870213</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.920900</td>
#       <td>0.454164</td>
#       <td>-0.063291</td>
#       <td>-0.068063</td>
#       <td>0.617347</td>
#       <td>0.004772</td>
#       <td>-0.632908</td>
#       <td>-0.680626</td>
#       <td>-1.820860</td>
#       <td>-1.821279</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.874300</td>
#       <td>0.448935</td>
#       <td>-0.061793</td>
#       <td>-0.066214</td>
#       <td>0.627551</td>
#       <td>0.004421</td>
#       <td>-0.617925</td>
#       <td>-0.662139</td>
#       <td>-1.838470</td>
#       <td>-1.838186</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.924400</td>
#       <td>0.443710</td>
#       <td>-0.060274</td>
#       <td>-0.065057</td>
#       <td>0.607143</td>
#       <td>0.004783</td>
#       <td>-0.602738</td>
#       <td>-0.650569</td>
#       <td>-1.825914</td>
#       <td>-1.825607</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.880900</td>
#       <td>0.439925</td>
#       <td>-0.059213</td>
#       <td>-0.064310</td>
#       <td>0.627551</td>
#       <td>0.005097</td>
#       <td>-0.592132</td>
#       <td>-0.643098</td>
#       <td>-1.829996</td>
#       <td>-1.829730</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.909600</td>
#       <td>0.438334</td>
#       <td>-0.058914</td>
#       <td>-0.064496</td>
#       <td>0.612245</td>
#       <td>0.005582</td>
#       <td>-0.589135</td>
#       <td>-0.644957</td>
#       <td>-1.827477</td>
#       <td>-1.827544</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.970500</td>
#       <td>0.437228</td>
#       <td>-0.058764</td>
#       <td>-0.064436</td>
#       <td>0.632653</td>
#       <td>0.005671</td>
#       <td>-0.587645</td>
#       <td>-0.644358</td>
#       <td>-1.823760</td>
#       <td>-1.823694</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.818200</td>
#       <td>0.435844</td>
#       <td>-0.058380</td>
#       <td>-0.064206</td>
#       <td>0.637755</td>
#       <td>0.005826</td>
#       <td>-0.583803</td>
#       <td>-0.642064</td>
#       <td>-1.818651</td>
#       <td>-1.818510</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.849200</td>
#       <td>0.435317</td>
#       <td>-0.058182</td>
#       <td>-0.064013</td>
#       <td>0.632653</td>
#       <td>0.005831</td>
#       <td>-0.581817</td>
#       <td>-0.640126</td>
#       <td>-1.820451</td>
#       <td>-1.820303</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=1.0661615699529647, metrics={'train_runtime': 1777.1739, 'train_samples_per_second': 0.45, 'train_steps_per_second': 0.056, 'total_flos': 0.0, 'train_loss': 1.0661615699529647, 'epoch': 1.0310880829015545})

# %%
FastLanguageModel.for_inference(model)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): Qwen2ForCausalLM(
#       (model): Qwen2Model(
#         (embed_tokens): Embedding(152064, 5120, padding_idx=151654)
#         (layers): ModuleList(
#           (0-63): 64 x Qwen2DecoderLayer(
#             (self_attn): Qwen2Attention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=5120, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=1024, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=1024, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=5120, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): Qwen2MLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=27648, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=27648, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=27648, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=27648, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=27648, out_features=5120, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=27648, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): Qwen2RMSNorm((5120,), eps=1e-05)
#             (post_attention_layernorm): Qwen2RMSNorm((5120,), eps=1e-05)
#           )
#         )
#         (norm): Qwen2RMSNorm((5120,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=5120, out_features=152064, bias=False)
#     )
#   )
# )

# %%
model.eval()
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): Qwen2ForCausalLM(
#       (model): Qwen2Model(
#         (embed_tokens): Embedding(152064, 5120, padding_idx=151654)
#         (layers): ModuleList(
#           (0-63): 64 x Qwen2DecoderLayer(
#             (self_attn): Qwen2Attention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=5120, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=1024, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=1024, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=5120, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): Qwen2MLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=27648, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=27648, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=5120, out_features=27648, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=5120, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=27648, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=27648, out_features=5120, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=27648, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=5120, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): Qwen2RMSNorm((5120,), eps=1e-05)
#             (post_attention_layernorm): Qwen2RMSNorm((5120,), eps=1e-05)
#           )
#         )
#         (norm): Qwen2RMSNorm((5120,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=5120, out_features=152064, bias=False)
#     )
#   )
# )

# %%
test_prompt = """
Your task is to analyze the content of a given tweet and classify it based on the following emotion labels:

Emotion Labels: {Anger, Fear, Love, Surprise, Sadness, Joy, Anticipation, Disgust, Optimism, Pessimism, Trust}

Tweet: "I just want to kill him."

Instructions:

1. Analyze the Content: Thoroughly analyze the tweet's content, tone, and context. Look for linguistic cues, such as words, phrases, or implied sentiments that might indicate one or more emotions.

2. Chain of Thought Reasoning: Break down the tweet's components step by step. Consider the following questions as part of your reasoning:
2a. What is the speaker expressing?
2b. Does the speaker show a positive, negative, or neutral sentiment?
2c. Are there hints of longing, hope, frustration, or any other specific emotion?
2d. Is there any combination of emotions suggested by the words or tone?

3. Classify Emotions: Use the reasoning process to identify:
3a. The Most Prominent Emotion: Select the single most dominant emotion that captures the essence of the tweet.
3b. Other Present Emotions: List other emotions that might be present in the tweet, even if they are secondary.

4. Explain the Classification: Explain your classification. Clearly articulate:
4a. Why did you choose the most prominent emotion?
4b. Why do you believe the secondary emotions are present?
4c. Reference specific parts of the tweet that support your reasoning.
"""

# %%
inputs = tokenizer(test_prompt, return_tensors="pt", truncation=True, max_length=512)
inputs = {k: v.to(model.device) for k, v in inputs.items()}

# %%
with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=512,
        temperature=0.1,
        top_p=0.9,
        top_k=5,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id,
    )

generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
generated_text
# Out:
# '\nYour task is to analyze the content of a given tweet and classify it based on the following emotion labels:\n\nEmotion Labels: {Anger, Fear, Love, Surprise, Sadness, Joy, Anticipation, Disgust, Optimism, Pessimism, Trust}\n\nTweet: "I just want to kill him."\n\nInstructions:\n\n1. Analyze the Content: Thoroughly analyze the tweet\'s content, tone, and context. Look for linguistic cues, such as words, phrases, or implied sentiments that might indicate one or more emotions.\n\n2. Chain of Thought Reasoning: Break down the tweet\'s components step by step. Consider the following questions as part of your reasoning:\n2a. What is the speaker expressing?\n2b. Does the speaker show a positive, negative, or neutral sentiment?\n2c. Are there hints of longing, hope, frustration, or any other specific emotion?\n2d. Is there any combination of emotions suggested by the words or tone?\n\n3. Classify Emotions: Use the reasoning process to identify:\n3a. The Most Prominent Emotion: Select the single most dominant emotion that captures the essence of the tweet.\n3b. Other Present Emotions: List other emotions that might be present in the tweet, even if they are secondary.\n\n4. Explain the Classification: Explain your classification. Clearly articulate:\n4a. Why did you choose the most prominent emotion?\n4b. Why do you believe the secondary emotions are present?\n4c. Reference specific parts of the tweet that support your reasoning.\n{"explanation":"The tweet \'I just want to kill him.\' expresses a strong negative sentiment. The phrase \'want to kill him\' is a hyperbolic expression of extreme anger or frustration. The use of \'kill\' indicates a desire to harm, which is a clear indicator of anger. There is no indication of any positive emotions or neutral sentiment in the tweet. The tone is aggressive and hostile, which aligns with the emotion of anger. Additionally, the tweet could imply a sense of disgust if the speaker feels repulsed by the person they are referring to, but the primary emotion is anger due to the aggressive language used.","most_prominent_emotion":"Anger","multiple_emotions_present":["Anger","Disgust"]}'

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model.push_to_hub_merged("imhmdf/DeepSeek-R1-Distill-Qwen-32B-bnb-4bit-ORPO-tuned", tokenizer, save_method = "merged_16bit", token = "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")
# Out:
# Unsloth: You are pushing to hub, but you passed your HF username = imhmdf.
# We shall truncate imhmdf/DeepSeek-R1-Distill-Qwen-32B-bnb-4bit-ORPO-tuned to DeepSeek-R1-Distill-Qwen-32B-bnb-4bit-ORPO-tuned
# Unsloth: Kaggle/Colab has limited disk space. We need to delete the downloaded
# model which will save 4-16GB of disk space, allowing you to save on Kaggle/Colab.
# Unsloth: Will remove a cached repo with size 19.2G
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 49.71 out of 83.48 RAM for saving.
# Unsloth: Saving model... This might take 5 minutes ...
#  12%|█▎        | 8/64 [00:00<00:02, 25.39it/s]
# We will save to Disk and not RAM now.
# 100%|██████████| 64/64 [02:16<00:00,  2.14s/it]
# Unsloth: Saving tokenizer...
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
#  Done.
# README.md:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model-00003-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00011-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# Upload 14 LFS files:   0%|          | 0/14 [00:00<?, ?it/s]
# model-00005-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00013-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00004-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00006-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00012-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00001-of-00014.safetensors:   0%|          | 0.00/4.89G [00:00<?, ?B/s]
# model-00010-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00002-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00009-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00008-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00007-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00014-of-00014.safetensors:   0%|          | 0.00/2.12G [00:00<?, ?B/s]
# Done.
# Saved merged model to https://huggingface.co/imhmdf/DeepSeek-R1-Distill-Qwen-32B-bnb-4bit-ORPO-tuned

# %%
from enum import Enum
from typing import List, Optional
from pydantic import BaseModel

# %%
class SingleEmotion(str, Enum):
    anger = "anger"
    fear = "fear"
    sadness = "sadness"
    joy = "joy"
    love = "love"
    surprise = "surprise"
    neutral = "neutral"

class MultipleEmotion(str, Enum):
    anger = "anger"
    fear = "fear"
    sadness = "sadness"
    joy = "joy"
    love = "love"
    surprise = "surprise"
    anticipation = "anticipation"
    disgust = "disgust"
    optimism = "optimism"
    pessimism = "pessimism"
    trust = "trust"
    neutral = "neutral"

class EmotionOutput(BaseModel):
    explanation: str
    most_prominent_emotion: SingleEmotion
    multiple_emotions_present: Optional[List[MultipleEmotion]] = None
